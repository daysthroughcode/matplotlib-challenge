# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_md = pd.read_csv(mouse_metadata_path)
study_res = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_study = pd.merge(mouse_md, study_res, how ='inner', on ='Mouse ID')
mouse_study.columns = ['m_id', 'drug_reg', 'sex', 'age_mon', 'weight_g', 'timepoint', 'tumorvol_mm3', 'metastatic_sites']

# Display the data table for preview
mouse_study
# Out:
#       m_id  drug_reg   sex  age_mon  weight_g  timepoint  tumorvol_mm3  \
# 0     k403  Ramicane  Male       21        16          0     45.000000
# 1     k403  Ramicane  Male       21        16          5     38.825898
# 2     k403  Ramicane  Male       21        16         10     35.014271
# 3     k403  Ramicane  Male       21        16         15     34.223992
# 4     k403  Ramicane  Male       21        16         20     32.997729
# ...    ...       ...   ...      ...       ...        ...           ...
# 1888  z969  Naftisol  Male        9        30         25     63.145652
# 1889  z969  Naftisol  Male        9        30         30     65.841013
# 1890  z969  Naftisol  Male        9        30         35     69.176246
# 1891  z969  Naftisol  Male        9        30         40     70.314904
# 1892  z969  Naftisol  Male        9        30         45     73.867845
#
#       metastatic_sites
# 0                    0
# 1                    0
# 2                    1
# ...

# %%
mouse_study.shape
# Out:
# (1893, 8)

# %%
# Checking the number of mice.

#Sort by Mouse ID then Timepoint

mouse_study.sort_values(['m_id','timepoint'], ascending = False) 

#Count and Call Unique values

mouse_num = mouse_study['m_id'].nunique()
mouse_num
# Out:
# 249

# %%
#Modify data to use Mouse ID as index

mouse_index = mouse_study.set_index("m_id", drop = False)
mouse_index
# Out:
#       m_id  drug_reg   sex  age_mon  weight_g  timepoint  tumorvol_mm3  \
# m_id
# k403  k403  Ramicane  Male       21        16          0     45.000000
# k403  k403  Ramicane  Male       21        16          5     38.825898
# k403  k403  Ramicane  Male       21        16         10     35.014271
# k403  k403  Ramicane  Male       21        16         15     34.223992
# k403  k403  Ramicane  Male       21        16         20     32.997729
# ...    ...       ...   ...      ...       ...        ...           ...
# z969  z969  Naftisol  Male        9        30         25     63.145652
# z969  z969  Naftisol  Male        9        30         30     65.841013
# z969  z969  Naftisol  Male        9        30         35     69.176246
# z969  z969  Naftisol  Male        9        30         40     70.314904
# z969  z969  Naftisol  Male        9        30         45     73.867845
#
#       metastatic_sites
# m_id
# k403                 0
# k403                 0
# k403                 1
# ...

# %%
#Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicatemice = mouse_study[mouse_study.duplicated()]
duplicatemice
# Out:
#      m_id  drug_reg     sex  age_mon  weight_g  timepoint  tumorvol_mm3  \
# 909  g989  Propriva  Female       21        26          0          45.0
#
#      metastatic_sites
# 909                 0

# %%
# Optional: Get all the data for the duplicate mouse ID. 

mouse_index.loc["g989",:]
# Out:
#       m_id  drug_reg     sex  age_mon  weight_g  timepoint  tumorvol_mm3  \
# m_id
# g989  g989  Propriva  Female       21        26          0     45.000000
# g989  g989  Propriva  Female       21        26          0     45.000000
# g989  g989  Propriva  Female       21        26          5     48.786801
# g989  g989  Propriva  Female       21        26          5     47.570392
# g989  g989  Propriva  Female       21        26         10     51.745156
# g989  g989  Propriva  Female       21        26         10     49.880528
# g989  g989  Propriva  Female       21        26         15     51.325852
# g989  g989  Propriva  Female       21        26         15     53.442020
# g989  g989  Propriva  Female       21        26         20     55.326122
# g989  g989  Propriva  Female       21        26         20     54.657650
# g989  g989  Propriva  Female       21        26         25     56.045564
# g989  g989  Propriva  Female       21        26         30     59.082294
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_indcln = mouse_index.drop('g989')
mouse_indcln.shape
# Out:
# (1880, 8)

# %%
# Checking the number of mice in the clean DataFrame.
mouse_numcln = mouse_indcln['m_id'].nunique()
mouse_numcln
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
mse_mean = round(mouse_indcln["tumorvol_mm3"].mean(),2)
mse_median = round(mouse_indcln["tumorvol_mm3"].median(),2)
mse_var = round(mouse_indcln["tumorvol_mm3"].var(),2)
mse_sd = round(mouse_indcln["tumorvol_mm3"].std(),2)
mse_sem = round(mouse_indcln["tumorvol_mm3"].sem(),2)

sumstat1 = dict()
sumstat1['Mean'] = str(mse_mean)
sumstat1['Median'] = str(mse_median)
sumstat1['Variance'] = str(mse_var)
sumstat1['Standard Deviation'] = str(mse_sd)
sumstat1['Standard Error of Mean'] = str(mse_sem)

sumstat1df = pd.DataFrame(list(sumstat1.items()), index=[' ', ' ', ' ', ' ', ' '], columns =('Summary Statistic','Value'))
# This method is the most straighforward, creating multiple series and putting them all together at the end.

sumstat1df
# Out:
#         Summary Statistic  Value
#                      Mean  50.44
#                    Median  48.93
#                  Variance  79.46
#        Standard Deviation   8.91
#    Standard Error of Mean   0.21

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

sumstat2 = round(mouse_indcln["tumorvol_mm3"].mean(),2), 
round(mouse_indcln["tumorvol_mm3"].median(),2),
round(mouse_indcln["tumorvol_mm3"].var(),2),
round(mouse_indcln["tumorvol_mm3"].std(),2),
round(mouse_indcln["tumorvol_mm3"].sem(),2)

sumstat2

# This method produces everything in a single groupby function
# Out:
# (50.44,)

# %% [markdown]
# ## Bar and Pie Charts

# %%
mouse_indcln.drug_reg.unique()
# Out:
# array(['Ramicane', 'Capomulin', 'Infubinol', 'Placebo', 'Ceftamin',
#        'Stelasyn', 'Zoniferol', 'Ketapril', 'Propriva', 'Naftisol'],
#       dtype=object)

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
drug_ct = mouse_indcln.drug_reg.value_counts()
drug_ctdf = pd.DataFrame(drug_ct)
drug_ctdf.columns = ['Count']
drug_ctdf.plot(drug_ct, kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-a4881cb1cf3d> in <module>
#       3 drug_ctdf = pd.DataFrame(drug_ct)
#       4 drug_ctdf.columns = ['Count']
# ----> 5 drug_ctdf.plot(drug_ct, kind = "bar")
#
# ~/opt/anaconda3/envs/class_31/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     912                 if is_integer(x) and not data.columns.holds_integer():
#     913                     x = data_cols[x]
# --> 914                 elif not isinstance(data[x], ABCSeries):
#     915                     raise ValueError("x must be a label or position")
#     916                 data = data.set_index(x)
#
# ~/opt/anaconda3/envs/class_31/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# ...

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
