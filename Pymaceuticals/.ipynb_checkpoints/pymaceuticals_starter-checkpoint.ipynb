# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_md = pd.read_csv(mouse_metadata_path)
study_res = pd.read_csv(study_results_path)

# Combine the data into a single dataset
mouse_study = pd.merge(mouse_md, study_res, how ='inner', on ='Mouse ID')


# Display the data table for preview
mouse_study
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
mouse_study.shape
# Out:
# (1893, 8)

# %%
# Checking the number of mice.

#Sort by Mouse ID then Timepoint

mouse_study.sort_values(['Mouse ID','Timepoint'], ascending = False) 

#Count and Call Unique values

mouse_num = mouse_study['Mouse ID'].nunique()
mouse_num
# Out:
# 249

# %%
#Modify data to use Mouse ID as index

mouse_index = mouse_study.set_index("Mouse ID", drop = False)
mouse_index
# Out:
#          Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# k403         k403     Ramicane  Male          21          16          0
# k403         k403     Ramicane  Male          21          16          5
# k403         k403     Ramicane  Male          21          16         10
# k403         k403     Ramicane  Male          21          16         15
# k403         k403     Ramicane  Male          21          16         20
# ...           ...          ...   ...         ...         ...        ...
# z969         z969     Naftisol  Male           9          30         25
# z969         z969     Naftisol  Male           9          30         30
# z969         z969     Naftisol  Male           9          30         35
# z969         z969     Naftisol  Male           9          30         40
# z969         z969     Naftisol  Male           9          30         45
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# k403               45.000000                 0
# k403               38.825898                 0
# k403               35.014271                 1
# k403               34.223992                 1
# k403               32.997729                 1
# ...                      ...               ...
# z969               63.145652                 2
# z969               65.841013                 3
# z969               69.176246                 4
# z969               70.314904                 4
# z969               73.867845                 4
#
# [1893 rows x 8 columns]

# %%
#Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicatemice = mouse_study[mouse_study.duplicated()]
duplicatemice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909                45.0                 0

# %%
# Optional: Get all the data for the duplicate mouse ID. 

mouse_index.loc["g989",:]
# Out:
#          Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         g989     Propriva  Female          21          26          0
# g989         g989     Propriva  Female          21          26          0
# g989         g989     Propriva  Female          21          26          5
# g989         g989     Propriva  Female          21          26          5
# g989         g989     Propriva  Female          21          26         10
# g989         g989     Propriva  Female          21          26         10
# g989         g989     Propriva  Female          21          26         15
# g989         g989     Propriva  Female          21          26         15
# g989         g989     Propriva  Female          21          26         20
# g989         g989     Propriva  Female          21          26         20
# g989         g989     Propriva  Female          21          26         25
# g989         g989     Propriva  Female          21          26         30
# g989         g989     Propriva  Female          21          26         35
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# g989               45.000000                 0
# g989               45.000000                 0
# g989               48.786801                 0
# g989               47.570392                 0
# g989               51.745156                 0
# g989               49.880528                 0
# g989               51.325852                 1
# g989               53.442020                 0
# g989               55.326122                 1
# g989               54.657650                 1
# g989               56.045564                 1
# g989               59.082294                 1
# g989               62.570880                 2

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mouse_indcln = mouse_index.drop('g989')
mouse_indcln.shape
# Out:
# (1880, 8)

# %%
# Checking the number of mice in the clean DataFrame.
mouse_numcln = mouse_indcln['Mouse ID'].nunique()
mouse_numcln
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
mse_mean = round(mouse_indcln["Tumor Volume (mm3)"].mean(),2)
mse_median = round(mouse_indcln["Tumor Volume (mm3)"].median(),2)
mse_var = round(mouse_indcln["Tumor Volume (mm3)"].var(),2)
mse_sd = round(mouse_indcln["Tumor Volume (mm3)"].std(),2)
mse_sem = round(mouse_indcln["Tumor Volume (mm3)"].sem(),2)

sumstat1 = dict()
sumstat1['Mean'] = str(mse_mean)
sumstat1['Median'] = str(mse_median)
sumstat1['Variance'] = str(mse_var)
sumstat1['Standard Deviation'] = str(mse_sd)
sumstat1['Standard Error of Mean'] = str(mse_sem)

sumstat1df = pd.DataFrame(list(sumstat1.items()), index=[' ', ' ', ' ', ' ', ' '], columns =('Summary Statistic','Value'))
# This method is the most straighforward, creating multiple series and putting them all together at the end.

sumstat1df
# Out:
#         Summary Statistic  Value
#                      Mean  50.44
#                    Median  48.93
#                  Variance  79.46
#        Standard Deviation   8.91
#    Standard Error of Mean   0.21

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

sumstat2 = st.describe(mouse_indcln["Tumor Volume (mm3)"])
sumstat2

# This method produces everything in a single groupby function
# Out:
# DescribeResult(nobs=1880, minmax=(22.05012627, 78.56701362), mean=50.43529323225532, variance=79.46290714557323, skewness=0.3012677175349431, kurtosis=0.030488631190233484)

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas.

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse


# Merge this group df with the original dataframe to get the tumor volume at the last timepoint

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
